# %% [markdown]
# <a href="https://colab.research.google.com/github/Charanraju18/Deep-Learning-Lab/blob/main/DL_Lab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# experiment 1

import numpy as np
from tensorflow.keras.datasets import mnist # Load MNIST dataset
from tensorflow.keras.models import Sequential # Define a sequential neural network
from tensorflow.keras.layers import Dense, Dropout # Add dense and dropout layers
from tensorflow.keras.utils import to_categorical # One-hot encoding of labels

# Step 1: Load the MNIST dataset
print("Loading the MNIST dataset...")
# The dataset contains grayscale images of handwritten digits (28x28 pixels) and corresponding labels
(X_train, y_train), (X_test, y_test) = mnist.load_data()
print(f"Training data shape: {X_train.shape}, Training labels shape: {y_train.shape}")
print(f"Testing data shape: {X_test.shape}, Testing labels shape: {y_test.shape}")

# Step 2: Reshape input data
print("\nReshaping the input data...")
# Reshape images from 28x28 pixels into 1D arrays of size 784
X_train = X_train.reshape(X_train.shape[0], 28*28)
X_test = X_test.reshape(X_test.shape[0], 28*28)
print(f"Reshaped training data shape: {X_train.shape}")
print(f"Reshaped testing data shape: {X_test.shape}")

# Step 3: Normalize input data
print("\nNormalizing the input data...")
# Normalize pixel values to the range 0-1 by dividing by 255
X_train = X_train / 255.0
X_test = X_test / 255.0
print("Normalization complete. Pixel values are now between 0 and 1.")

# Step 4: One-hot encode target variables
print("\nOne-hot encoding the target variables...")
# Convert integer labels (0-9) into one-hot encoded vectors
y_train = to_categorical(y_train)
y_test = to_categorical(y_test)
print(f"Encoded training labels shape: {y_train.shape}")
print(f"Encoded testing labels shape: {y_test.shape}")

# Step 5: Define the MLP (Multi-Layer Perceptron) model
print("\nDefining the neural network model...")
# Create a Sequential model
model = Sequential()
# Add the first hidden layer with 512 units and ReLU activation
model.add(Dense(512, input_shape=(784,), activation='relu'))
# Add a dropout layer to reduce overfitting
model.add(Dropout(0.2))
# Add a second hidden layer with 512 units and ReLU activation
model.add(Dense(512, activation='relu'))
# Add another dropout layer
model.add(Dropout(0.2))
# Add the output layer with 10 units (for 10 classes) and softmax activation
model.add(Dense(10, activation='softmax'))
print("Model architecture defined.")

# Step 6: Compile the model
print("\nCompiling the model...")
# Compile the model with categorical cross-entropy loss, Adam optimizer, and accuracy metric
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
print("Model compiled with categorical cross-entropy loss and Adam optimizer.")

# Step 7: Train the model
print("\nStarting training...")
# Train the model on the training data, using the test data for validation
# Set the number of epochs to 10 and batch size to 128
history = model.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=10, batch_size=128,verbose=1)
print("Training complete.")

# Step 8: Evaluate the model on test data
print("\nEvaluating the model on test data...")
# Evaluate the model's performance on the test data
scores = model.evaluate(X_test, y_test, verbose=0)
# Print the test accuracy
print(f"Test Accuracy: {scores[1] * 100:.2f}%")
# Additional: Display training history
print("\nTraining history:")
# Print the final training accuracy
print(f"Training accuracy: {history.history['accuracy'][-1]:.2f}")
# Print the final validation accuracy
print(f"Validation accuracy: {history.history['val_accuracy'][-1]:.2f}")
# Out:
# Loading data...
# Training data shape: (60000, 28, 28), Testing labels shape: (60000,)
# Testing data shape: (10000, 28, 28), Testing labels shape: (10000,)
# reshaping data...
# reshaped training data shape: (60000, 784), reshaped testing data shape: (10000, 784)
# normalizing data...
# Normalization complete. Pixel values are now between 0 and 1.
# one-hot encoding labels...
# Encoded training labels shape: (60000, 10), encoded testing labels shape: (10000, 10)
# Defining model...
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model architecture defined
# Compiling model...
# Model compiled
# Training model...
# Epoch 1/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 12s 24ms/step - accuracy: 0.8641 - loss: 0.4511 - val_accuracy: 0.9662 - val_loss: 0.1045
# Epoch 2/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 11s 24ms/step - accuracy: 0.9688 - loss: 0.1003 - val_accuracy: 0.9737 - val_loss: 0.0841
# Epoch 3/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 20s 22ms/step - accuracy: 0.9778 - loss: 0.0706 - val_accuracy: 0.9785 - val_loss: 0.0702
# Epoch 4/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 11s 23ms/step - accuracy: 0.9826 - loss: 0.0538 - val_accuracy: 0.9809 - val_loss: 0.0646
# Epoch 5/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 21s 24ms/step - accuracy: 0.9868 - loss: 0.0415 - val_accuracy: 0.9824 - val_loss: 0.0628
# Epoch 6/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 10s 20ms/step - accuracy: 0.9881 - loss: 0.0358 - val_accuracy: 0.9798 - val_loss: 0.0654
# Epoch 7/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 11s 22ms/step - accuracy: 0.9896 - loss: 0.0306 - val_accuracy: 0.9805 - val_loss: 0.0688
# Epoch 8/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 22s 25ms/step - accuracy: 0.9909 - loss: 0.0282 - val_accuracy: 0.9770 - val_loss: 0.0820
# Epoch 9/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 11s 24ms/step - accuracy: 0.9911 - loss: 0.0262 - val_accuracy: 0.9813 - val_loss: 0.0702
# Epoch 10/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 10s 20ms/step - accuracy: 0.9924 - loss: 0.0228 - val_accuracy: 0.9818 - val_loss: 0.0710
# Model trained
# Evaluating model...
# Test accuracy: 0.9818000197410583
# Training history:
# Training accuracy: 0.991266667842865
# Validation accuracy: 0.9818000197410583

# %%
#experiment 2

from tensorflow.keras.datasets import imdb
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.preprocessing.sequence import pad_sequences


(x_train, y_train), (x_test, y_test) = imdb.load_data(num_words=10000)

maxlen = 200
x_train = pad_sequences(x_train, maxlen=maxlen)
x_test = pad_sequences(x_test, maxlen=maxlen)

model = Sequential()
model.add(Dense(128, activation='relu', input_shape=(maxlen,)))
model.add(Dropout(0.5))
model.add(Dense(64, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(1, activation='sigmoid'))

model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

model.fit(x_train, y_train, batch_size=128, epochs=10, validation_data=(x_test, y_test))

scores = model.evaluate(x_test, y_test, verbose=0)
print("Accuracy: %.2f%%" % (scores[1]*100))

from sklearn.metrics import classification_report
y_pred = (model.predict(x_test)>0.5).astype("int32")
print(classification_report(y_test, y_pred,target_names=["Negative","Positive"]))


from sklearn.metrics import confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt

# Generate the confusion matrix
cm = confusion_matrix(y_test, y_pred)

# Visualize the confusion matrix
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=["Negative", "Positive"],
yticklabels=["Negative", "Positive"])
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.title("Confusion Matrix")
plt.show()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/imdb.npz
# 17464789/17464789 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Epoch 1/10
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.5033 - loss: 430.2294 - val_accuracy: 0.5052 - val_loss: 1.6716
# Epoch 2/10
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.4997 - loss: 19.5655 - val_accuracy: 0.5034 - val_loss: 0.7158
# Epoch 3/10
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.5035 - loss: 3.5273 - val_accuracy: 0.5057 - val_loss: 0.6955
# Epoch 4/10
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.4985 - loss: 1.7917 - val_accuracy: 0.5013 - val_loss: 0.6952
# Epoch 5/10
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.5043 - loss: 1.4237 - val_accuracy: 0.4994 - val_loss: 0.6951
# Epoch 6/10
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.4863 - loss: 1.2281 - val_accuracy: 0.4978 - val_loss: 0.6957
# Epoch 7/10
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.4981 - loss: 0.8842 - val_accuracy: 0.4992 - val_loss: 0.6935
# Epoch 8/10
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.5070 - loss: 0.9135 - val_accuracy: 0.5011 - val_loss: 0.6934
# Epoch 9/10
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - accuracy: 0.5007 - loss: 0.8566 - val_accuracy: 0.4994 - val_loss: 0.6935
# Epoch 10/10
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step - accuracy: 0.4953 - loss: 0.7998 - val_accuracy: 0.5000 - val_loss: 0.6934
# Accuracy: 50.00%
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step
#               precision    recall  f1-score   support
#
#     Negative       0.50      0.98      0.66     12500
#     Positive       0.50      0.02      0.03     12500
#
#     accuracy                           0.50     25000
#    macro avg       0.50      0.50      0.35     25000
# weighted avg       0.50      0.50      0.35     25000

# %%
#experiment 3

import numpy as np
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.datasets import reuters
from tensorflow.keras.utils import to_categorical

(x_train, y_train), (x_test, y_test) = reuters.load_data(num_words=10000)
from tensorflow.keras.preprocessing.sequence import pad_sequences
max_len = 200
x_train = pad_sequences(x_train, maxlen=max_len)
x_test = pad_sequences(x_test, maxlen=max_len)
model=Sequential()
model.add(Dense(128, activation='relu', input_dim=(max_len)))
model.add(Dropout(0.5))
model.add(Dense(64, activation='relu'))
model.add(Dropout(0.5))
# Change the output layer to have 46 units and softmax activation for multi-class classification
model.add(Dense(46, activation='softmax')) # Changed from 1 to 46 and sigmoid to softmax
model.compile(loss='sparse_categorical_crossentropy', optimizer='adam', metrics=['accuracy']) # Changed loss to sparse_categorical_crossentropy
model.fit(x_train, y_train, epochs=10, batch_size=128, validation_data=(x_test, y_test))
scores = model.evaluate(x_test, y_test, verbose=0)
print("Accuracy: %.2f%%" % (scores[1]*100))

# Get predicted class labels
y_pred = np.argmax(model.predict(x_test), axis=-1)

from sklearn.metrics import classification_report,confusion_matrix
# Get all unique class labels from y_test
target_names = [str(i) for i in np.unique(y_test)]  # Generate target names for all classes
print(classification_report(y_test, y_pred, target_names=target_names))
import seaborn as sns
import matplotlib.pyplot as plt
cm=confusion_matrix(y_test, y_pred)
plt.figure(figsize=(8,6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',xticklabels=target_names, yticklabels=target_names)  # Use target_names for heatmap labels
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix')
plt.show()
# Out:
# Epoch 1/10
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.0494 - loss: 1646.6417 - val_accuracy: 0.2271 - val_loss: 22.3157
# Epoch 2/10
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.1459 - loss: 165.0890 - val_accuracy: 0.2159 - val_loss: 3.6861
# Epoch 3/10
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.2026 - loss: 29.1413 - val_accuracy: 0.2115 - val_loss: 3.6122
# Epoch 4/10
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.2150 - loss: 13.2917 - val_accuracy: 0.2110 - val_loss: 3.5326
# Epoch 5/10
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.2196 - loss: 8.7689 - val_accuracy: 0.2110 - val_loss: 3.4563
# Epoch 6/10
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.2048 - loss: 6.7043 - val_accuracy: 0.2110 - val_loss: 3.3842
# Epoch 7/10
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.2191 - loss: 5.9449 - val_accuracy: 0.2110 - val_loss: 3.3161
# Epoch 8/10
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.2220 - loss: 5.1959 - val_accuracy: 0.2110 - val_loss: 3.2512
# Epoch 9/10
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.2158 - loss: 5.2515 - val_accuracy: 0.2110 - val_loss: 3.1900
# Epoch 10/10
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.2180 - loss: 4.5684 - val_accuracy: 0.2110 - val_loss: 3.1315
# Accuracy: 21.10%
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00        12
#            1       0.00      0.00      0.00       105
#            2       0.00      0.00      0.00        20
#            3       0.00      0.00      0.00       813
#            4       0.21      1.00      0.35       474
#            5       0.00      0.00      0.00         5
#            6       0.00      0.00      0.00        14
#            7       0.00      0.00      0.00         3
#            8       0.00      0.00      0.00        38
#            9       0.00      0.00      0.00        25
#           10       0.00      0.00      0.00        30
#           11       0.00      0.00      0.00        83
#           12       0.00      0.00      0.00        13
#           13       0.00      0.00      0.00        37
#           14       0.00      0.00      0.00         2
#           15       0.00      0.00      0.00         9
#           16       0.00      0.00      0.00        99
#           17       0.00      0.00      0.00        12
#           18       0.00      0.00      0.00        20
#           19       0.00      0.00      0.00       133
#           20       0.00      0.00      0.00        70
#           21       0.00      0.00      0.00        27
#           22       0.00      0.00      0.00         7
#           23       0.00      0.00      0.00        12
#           24       0.00      0.00      0.00        19
#           25       0.00      0.00      0.00        31
#           26       0.00      0.00      0.00         8
#           27       0.00      0.00      0.00         4
#           28       0.00      0.00      0.00        10
#           29       0.00      0.00      0.00         4
#           30       0.00      0.00      0.00        12
#           31       0.00      0.00      0.00        13
#           32       0.00      0.00      0.00        10
#           33       0.00      0.00      0.00         5
#           34       0.00      0.00      0.00         7
#           35       0.00      0.00      0.00         6
#           36       0.00      0.00      0.00        11
#           37       0.00      0.00      0.00         2
#           38       0.00      0.00      0.00         3
#           39       0.00      0.00      0.00         5
#           40       0.00      0.00      0.00        10
#           41       0.00      0.00      0.00         8
#           42       0.00      0.00      0.00         3
#           43       0.00      0.00      0.00         6
#           44       0.00      0.00      0.00         5
#           45       0.00      0.00      0.00         1
#
#     accuracy                           0.21      2246
#    macro avg       0.00      0.02      0.01      2246
# weighted avg       0.04      0.21      0.07      2246
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %%
#experiment 4

from tensorflow.keras.datasets import boston_housing
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.utils import normalize

(x_train, y_train), (x_test, y_test) = boston_housing.load_data()

from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
x_train = scaler.fit_transform(x_train)
x_test = scaler.transform(x_test)
# Define the neural network architecture
model = Sequential()
model.add(Dense(64, activation='relu', input_shape=(13,)))
model.add(Dense(64, activation='relu'))
model.add(Dense(1))
model.compile(optimizer='adam', loss='mse')
history = model.fit(x_train, y_train,
 epochs=100,
 batch_size=32,
 validation_data=(x_test, y_test))
test_loss = model.evaluate(x_test, y_test)
print('Test loss:', test_loss)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/boston_housing.npz
# 57026/57026 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Epoch 1/100
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - loss: 593.0212 - val_loss: 559.4493
# Epoch 2/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 515.7534 - val_loss: 496.4765
# Epoch 3/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 463.1323 - val_loss: 411.7852
# Epoch 4/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 366.7285 - val_loss: 299.6329
# Epoch 5/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 256.7733 - val_loss: 177.1605
# Epoch 6/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 139.5426 - val_loss: 89.7121
# Epoch 7/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 71.6942 - val_loss: 56.6555
# Epoch 8/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 48.2030 - val_loss: 42.8325
# Epoch 9/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 38.4485 - val_loss: 34.1999
# Epoch 10/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 31.2158 - val_loss: 30.0629
# Epoch 11/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 20.8289 - val_loss: 27.9369
# Epoch 12/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 21.3666 - val_loss: 26.4842
# Epoch 13/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 21.9580 - val_loss: 25.6787
# Epoch 14/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 22.9342 - val_loss: 25.1050
# Epoch 15/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 16.6168 - val_loss: 24.6230
# Epoch 16/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 16.3723 - val_loss: 24.5947
# Epoch 17/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 18.8112 - val_loss: 24.9761
# Epoch 18/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 15.2513 - val_loss: 24.6598
# Epoch 19/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 16.6368 - val_loss: 24.3678
# Epoch 20/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 14.1074 - val_loss: 23.8938
# Epoch 21/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 13.3465 - val_loss: 24.2972
# Epoch 22/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 14.0922 - val_loss: 24.0765
# Epoch 23/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 15.1847 - val_loss: 24.2838
# Epoch 24/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 10.0611 - val_loss: 24.0950
# Epoch 25/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 11.4097 - val_loss: 24.0766
# Epoch 26/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 11.4032 - val_loss: 23.6408
# Epoch 27/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 14.3681 - val_loss: 24.5036
# Epoch 28/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 11.9153 - val_loss: 24.3717
# Epoch 29/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 14.6460 - val_loss: 23.7692
# Epoch 30/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 12.5567 - val_loss: 23.8658
# Epoch 31/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 12.1032 - val_loss: 23.6597
# Epoch 32/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 10.1114 - val_loss: 23.6058
# Epoch 33/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 9.4952 - val_loss: 23.6959
# Epoch 34/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 13.3299 - val_loss: 23.5415
# Epoch 35/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 10.5207 - val_loss: 23.3268
# Epoch 36/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 13.4474 - val_loss: 23.5679
# Epoch 37/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 11.7524 - val_loss: 23.5235
# Epoch 38/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 11.7763 - val_loss: 23.4569
# Epoch 39/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 12.3575 - val_loss: 23.9030
# Epoch 40/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 9.2871 - val_loss: 22.9735
# Epoch 41/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 8.7007 - val_loss: 23.6798
# Epoch 42/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 9.3640 - val_loss: 24.2082
# Epoch 43/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 9.1825 - val_loss: 22.9731
# Epoch 44/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 11.3665 - val_loss: 23.4175
# Epoch 45/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 8.2975 - val_loss: 23.3345
# Epoch 46/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 12.0941 - val_loss: 23.2301
# Epoch 47/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 9.1034 - val_loss: 22.6817
# Epoch 48/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 9.9147 - val_loss: 24.1761
# Epoch 49/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 8.2731 - val_loss: 23.2070
# Epoch 50/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 11.7904 - val_loss: 23.4295
# Epoch 51/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 9.3071 - val_loss: 22.1207
# Epoch 52/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 7.2535 - val_loss: 23.2231
# Epoch 53/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 7.1355 - val_loss: 22.8665
# Epoch 54/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 8.7951 - val_loss: 22.9011
# Epoch 55/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 10.3154 - val_loss: 22.9064
# Epoch 56/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 7.7679 - val_loss: 22.3030
# Epoch 57/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 8.5295 - val_loss: 22.4182
# Epoch 58/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 6.7488 - val_loss: 23.4842
# Epoch 59/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 7.2925 - val_loss: 22.6863
# Epoch 60/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 7.7326 - val_loss: 22.4175
# Epoch 61/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 9.6126 - val_loss: 23.0249
# Epoch 62/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 8.6467 - val_loss: 21.7153
# Epoch 63/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 6.9562 - val_loss: 22.1287
# Epoch 64/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 7.7662 - val_loss: 22.7090
# Epoch 65/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 10.1303 - val_loss: 22.6919
# Epoch 66/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 8.6643 - val_loss: 21.9738
# Epoch 67/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 8.6642 - val_loss: 20.9988
# Epoch 68/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 8.0291 - val_loss: 22.8899
# Epoch 69/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 9.7730 - val_loss: 21.8879
# Epoch 70/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 8.0138 - val_loss: 21.4006
# Epoch 71/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 7.7668 - val_loss: 22.2471
# Epoch 72/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 7.6026 - val_loss: 22.1881
# Epoch 73/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 8.1302 - val_loss: 21.6797
# Epoch 74/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 8.9490 - val_loss: 22.1805
# Epoch 75/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 7.5095 - val_loss: 21.7034
# Epoch 76/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 8.1149 - val_loss: 21.4346
# Epoch 77/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 7.2168 - val_loss: 21.4262
# Epoch 78/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 9.1278 - val_loss: 21.5347
# Epoch 79/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6.6395 - val_loss: 21.4068
# Epoch 80/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 7.6808 - val_loss: 22.5330
# Epoch 81/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 8.0087 - val_loss: 20.8173
# Epoch 82/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 7.4903 - val_loss: 21.1820
# Epoch 83/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 7.0737 - val_loss: 22.1237
# Epoch 84/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 6.4258 - val_loss: 21.1214
# Epoch 85/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 6.2542 - val_loss: 21.0838
# Epoch 86/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 8.2377 - val_loss: 21.7365
# Epoch 87/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 7.6775 - val_loss: 21.1966
# Epoch 88/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6.1473 - val_loss: 20.6529
# Epoch 89/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 8.2081 - val_loss: 21.4630
# Epoch 90/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 6.2983 - val_loss: 20.7574
# Epoch 91/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 8.1787 - val_loss: 21.2377
# Epoch 92/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 7.0159 - val_loss: 20.3440
# Epoch 93/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6.1761 - val_loss: 21.0952
# Epoch 94/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 6.1475 - val_loss: 20.2384
# Epoch 95/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 7.0563 - val_loss: 20.7561
# Epoch 96/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 6.0709 - val_loss: 20.8925
# Epoch 97/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6.5565 - val_loss: 20.6624
# Epoch 98/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 7.5524 - val_loss: 20.6561
# Epoch 99/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.6952 - val_loss: 20.6587
# Epoch 100/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.7678 - val_loss: 20.7712
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 15.4040
# Test loss: 20.77118682861328
